# %%
#Write a Python program that checks if a number is greater than 10 and less than 50.
x=25
y=30
print(x>10 and y<35)
# Out:
# True

# %%
#Print True if the age is greater than 18 or equal to 18, else False.
age = 20
print(age >= 18)
# Out:
# True

# %%
#Take two boolean variables x = True and y = False. Print the result of x and y.
x = True
y = False

print(x and y)
# Out:
# False

# %%
#Use the or operator to check if either 5 > 10 or 2 < 8.
print(5 > 10 or 2 < 8)
# Out:
# True

# %%
#Write a program that checks if a number is not divisible by 3.
x=8
x%=3
print(x)
# Out:
# 2

# %%
#Print "Access Granted" if the password is "admin123" and length is at least 6 characters.
password = "admin123"

print("Access granted = ",password)
# Out:
# Access granted =  admin123

# %%
#Given two numbers, check if both are positive using logical operators.
x=(4)
y=(6)
print(x>6 and y<4)
# Out:
# False

# %%
#Write a Python expression using not that returns True if 5 != 10.
print(5!=10)
# Out:
# True
