# %%
#Q1: Given a list [100, 200, 300, 400, 500], print elements from index 1 to 3.

# %%
number=[100,200,300,400,500]
print(number[1:4])
# Out:
# [200, 300, 400]

# %%
#Q2:Find the largest and smallest numbers from the list [34, 78, 12, 99, 56].

# %%
list1=[34,78,12,99,56]
largest=max(list1)
smallest=min(list1)
print("largest number",largest)
print("smallest number",smallest)
# Out:
# largest number 99
# smallest number 12

# %%
#Q3: Delete the key "city" from the dictionary {"name": "Sara", "age": 23, "city": "London"}.

# %%
person = {"name": "Sara", "age": 23, "city": "London"}
del person["city"]
print(person)
# Out:
# {'name': 'Sara', 'age': 23}

# %%
#Q4:Add "marks": 95 to the dictionary {"name": "Bob", "age": 22}.

# %%
student = {"name": "Bob", "age": 22}
student["marks"] = 95
print(student)
# Out:
# {'name': 'Bob', 'age': 22, 'marks': 95}

# %%
#Q5: Given a tuple (10, 20, 30, 40, 50), print the first, third, and last elements.

# %%
numbers = (10, 20, 30, 40, 50)
print("First element:", numbers[0])
print("Third element:", numbers[2])
print("Last element:", numbers[-1])
# Out:
# First element: 10
# Third element: 30
# Last element: 50

# %%
#Q6: Find the number of elements in the tuple (1, 2, 3, 4, 5, 6).

# %%
numbers = (1, 2, 3, 4, 5, 6)
count = len(numbers)
print("Number of elements in the tuple:", count)
# Out:
# Number of elements in the tuple: 6

# %%
#Q7: Create a list of 5 integers and print its type.
num=[5,6,2,3,6]
print(type(num))
# Out:
# <class 'list'>

# %%
#Q8: Create a dictionary {"name": "Alice", "age": 25} and print its type.

# %%
person2={"name": "Alice", "age": 25}
print(type(person2))
# Out:
# <class 'dict'>

# %%
#Q9: Find the largest of three numbers.

# %%
numbers=(20,30,10)
largest=max(numbers)
print("largest number", largest)
# Out:
# largest number 30

# %%
#Q10: Check if a letter is a vowel or consonant.

# %%
letter = input("Enter a single letter: ")
if letter in 'aeiou':
    print(letter, "is a vowel.")
else:
    print(letter, "is a consonant.")
# Out:
# Enter a single letter: d
# d is a consonant.

# %%
#Q11: Check if a number is positive, negative, or zero.

# %%
number=float(input("enter a number"))
if number>0:
  print(number,"positive")
elif number<0:
  print(number,"negative")
else:
  print(number,"zero")
# Out:
# enter a number0
# 0.0 zero

# %%
#bonus question : Simple Calculator: Perform +, -, *, / operations based on user input.
number1=float(input("enter the first number"))
number2=float(input("enter the second number"))
num=number1+number2
print(num)
# Out:
# enter the first number5
# enter the second number6
# 11.0

# %%
number1=float(input("enter the first number"))
number2=float(input("enter the second number"))
num=number1-number2
print(num)
# Out:
# enter the first number6
# enter the second number2
# 4.0

# %%
number1=float(input("enter the first number"))
number2=float(input("enter the second number"))
num=number1*number2
print(num)
# Out:
# enter the first number5
# enter the second number6
# 30.0

# %%
number1=float(input("enter the first number"))
number2=float(input("enter the second number"))
num=number1/number2
print(num)
# Out:
# enter the first number1
# enter the second number6
# 0.16666666666666666
